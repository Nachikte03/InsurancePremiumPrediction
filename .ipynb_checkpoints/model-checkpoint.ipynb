# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import joblib
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
# %matplotlib inline

# %% [markdown]
# ### Data Collection and Analysis

# %%
# loading the data from csv file to a Pandas DataFrame
dataset = pd.read_csv('insurance.csv')

# %%
# first 5 rows of the dataframe
dataset.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# number of rows and columns
dataset.shape
# Out:
# (1338, 7)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# statistical Measures of the dataset
dataset.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# The expenses column values are right skewed since mean is greater than the median value high chances of having outliers.

# %%
cols= ['age','bmi','expenses']
for col in cols:
    sns.set()
    plt.figure(figsize=(6,6))
    sns.displot(insurance_dataset[col],kde=True)
    plt.title(col)
    plt.show()

# %%
cols= ['age','bmi','expenses']
for col in cols:
    sns.set()
    plt.figure(figsize=(6,6))
    sns.boxplot(data=dataset[col])
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize=(6,6))
plt.boxplot(dataset['age'])
plt.title(col)
plt.show()

# %%
cols = ['sex','children','smoker','region']
for col in cols:
    plt.figure(figsize=(6,6))
    c = sns.countplot(x=col, data=dataset)
    plt.title(col)
    plt.show()

# %%
corr=dataset.corr()
ax=sns.heatmap(corr,annot=True)
bottom,top = ax.get_ylim()
ax.set_ylim(bottom+0.5,top -0.5)
# Out:
# (4.5, -0.5)

# %% [markdown]
# ### Data Pre-processing and Feature Engineering

# %%
# encoding sex column
dataset.replace({'sex':{'male':0,'female':1}}, inplace=True)

3 # encoding 'smoker' column
dataset.replace({'smoker':{'yes':0,'no':1}}, inplace=True)

# encoding 'region' column
dataset.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}}, inplace=True)

# %%
# converting sex,region and smoker columns
df=pd.get_dummies(data=dataset,columns=['sex','region','smoker'])

# %%
sns.pairplot(dataset)

# %%
dataset.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       0       1  16884.92
# 1   18    0  33.8         1       1       0   1725.55
# 2   28    0  33.0         3       1       0   4449.46
# 3   33    0  22.7         0       1       3  21984.47
# 4   32    0  28.9         0       1       3   3866.86

# %% [markdown]
# ### Train test split data

# %%
y = dataset['expenses']
X = dataset.drop(columns='expenses',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %% [markdown]
# ### Model Training

# %%
# loading the Linear Regression model
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("intercept value is*****", reg.intercept_)
print("coeffeicint value is*****", reg.coef_)
# Out:
# intercept value is***** 11353.786163452989
# coeffeicint value is***** [   251.39669397     26.32572382    330.72237897    580.44718594
#  -23926.86739786    212.3609025 ]

# %%
print("Predicting the train data")
train_predict = reg.predict(X_train)
print("Predicting the test data")
test_predict = reg.predict(X_test)
print("MAE")
print("Train : ",mean_absolute_error(y_train,train_predict))
print("Test  : ",mean_absolute_error(y_test,test_predict))
print("====================================")
print("MSE")
print("Train : ",mean_squared_error(y_train,train_predict))
print("Test  : ",mean_squared_error(y_test,test_predict))
print("====================================")
import numpy as np
print("RMSE")
print("Train : ",np.sqrt(mean_squared_error(y_train,train_predict)))
print("Test  : ",np.sqrt(mean_squared_error(y_test,test_predict)))
print("====================================")
print("R^2")
print("Train : ",r2_score(y_train,train_predict))
print("Test  : ",r2_score(y_test,test_predict))
# Out:
# Predicting the train data
# Predicting the test data
# MAE
# Train :  4150.271508686155
# Test  :  4267.483409378517
# ...
# MSE
# Train :  36172405.672836475
# Test  :  38335409.48591062
# ...
# RMSE
# Train :  6014.349979244347
# Test  :  6191.559535844795
# ...
# R^2
# Train :  0.7515233180624388
# Test  :  0.7447382074449773

# %%
input_data = (31,1,25.74,0,1,0)

# changing input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = reg.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [3759.33603725]
# The insurance cost is USD  3759.336037250354

# %%
pickle.dump(reg,open('model.pkl','wb'))

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
print(model.predict([[31,1,25.74,0,1,0]]))
# Out:
# [3759.33603725]

# %%
joblib.dump(reg,"model.sav")
